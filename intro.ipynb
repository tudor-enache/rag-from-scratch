# %% [markdown]
# ## 0. Colab set-up + testing HF API
#
# Set-up connection to Google Drive in order to use API keys.

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %% [markdown]
# HF Inference tutorial:
# 1. Choose model from hub with "Inference Providers" tag (chose mistralai/Mistral-7B-v0.1)
# 2. Copy code snippet from model page.

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="featherless-ai",
    api_key=os.environ["HF_TOKEN"],
)

result = client.text_generation(
    "Can you please let us know more details about your ",
    model="mistralai/Mistral-7B-v0.1",
)

# %% [markdown]
# ## 1. Intro
#
# Running a simple prompt through a pipeline to learn about the libraries we'll be using.
#
# Libraries:
# - langchain_community: integrations for third-party software
# - tiktoken: OpenAI BPE tokenizer
# - langchain-openai: integrations for OpenAI
# - langchainhub: (?) API for connecting to the LangChain Hub (like the HuggingFace Hub?)
# - chromadb: create in-memory database
# - langchain: core package
#
# The original tutorial uses OpenAI for the backend.
#
# Let's use a free service in parallel / instead. I will use the HF API.
#
# For this we need these new libraries:
# - langchain-anthropic
# - ...

# %%
# install libraries
! pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain

# %%
# set-up LangSmith connection
# (platform for monitoring model)

import os
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"

import yaml
with open("config/langsmith.yaml", "r") as f:
    data = yaml.safe_load(f)
print(data)

os.environ["LANGCHAIN_API_KEY"] = data

# %%
import os
import yaml

notebook_dir = os.getcwd()
config_path = os.path.join(notebook_dir, "config", "langsmith.yaml")
print(notebook_dir)

with open(config_path, "r") as f:
    data = yaml.safe_load(f)
print(data)
